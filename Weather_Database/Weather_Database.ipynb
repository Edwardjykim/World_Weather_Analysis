# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(high= 90.000, low= -90.000, size=2000)
lngs = np.random.uniform(high= 180.000, low= -180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities =[]

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 760

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid="+weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city,
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | baracoa
# Processing Record 2 of Set 1 | aktau
# Processing Record 3 of Set 1 | galesong
# Processing Record 4 of Set 1 | hermanus
# Processing Record 5 of Set 1 | bud
# Processing Record 6 of Set 1 | neiafu
# Processing Record 7 of Set 1 | paita
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | antofagasta
# Processing Record 10 of Set 1 | buala
# Processing Record 11 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 1 | bethel
# Processing Record 13 of Set 1 | buta
# Processing Record 14 of Set 1 | marsh harbour
# Processing Record 15 of Set 1 | arraial do cabo
# Processing Record 16 of Set 1 | saint-francois
# Processing Record 17 of Set 1 | te anau
# Processing Record 18 of Set 1 | tuatapere
# Processing Record 19 of Set 1 | cayenne
# Processing Record 20 of Set 1 | poso
# Processing Record 21 of Set 1 | bluff
# Processing Record 22 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 1 | masty
# Processing Record 24 of Set 1 | lasa
# Processing Record 25 of Set 1 | afmadu
# City not found. Skipping...
# Processing Record 26 of Set 1 | thompson
# Processing Record 27 of Set 1 | nenjiang
# Processing Record 28 of Set 1 | avarua
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | luderitz
# Processing Record 31 of Set 1 | zunyi
# Processing Record 32 of Set 1 | hilo
# Processing Record 33 of Set 1 | rikitea
# Processing Record 34 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 35 of Set 1 | nyurba
# Processing Record 36 of Set 1 | barrow
# Processing Record 37 of Set 1 | labuan
# Processing Record 38 of Set 1 | nileshwar
# Processing Record 39 of Set 1 | cape town
# Processing Record 40 of Set 1 | nara
# Processing Record 41 of Set 1 | zhob
# Processing Record 42 of Set 1 | say
# Processing Record 43 of Set 1 | port alfred
# Processing Record 44 of Set 1 | harper
# Processing Record 45 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 46 of Set 1 | new norfolk
# Processing Record 47 of Set 1 | belmonte
# Processing Record 48 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 1 | southbridge
# Processing Record 50 of Set 1 | tuktoyaktuk
# Processing Record 1 of Set 2 | ayan
# Processing Record 2 of Set 2 | farah
# Processing Record 3 of Set 2 | jiddah
# City not found. Skipping...
# Processing Record 4 of Set 2 | bredasdorp
# Processing Record 5 of Set 2 | atar
# Processing Record 6 of Set 2 | port macquarie
# Processing Record 7 of Set 2 | yellowknife
# Processing Record 8 of Set 2 | bengkulu
# Processing Record 9 of Set 2 | mitchell
# Processing Record 10 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 2 | russell
# Processing Record 12 of Set 2 | busselton
# Processing Record 13 of Set 2 | santa fe
# Processing Record 14 of Set 2 | alindao
# Processing Record 15 of Set 2 | lagunas
# Processing Record 16 of Set 2 | vaitape
# Processing Record 17 of Set 2 | guadalupe victoria
# Processing Record 18 of Set 2 | moron
# Processing Record 19 of Set 2 | mataura
# Processing Record 20 of Set 2 | uspenka
# Processing Record 21 of Set 2 | tiksi
# Processing Record 22 of Set 2 | vila franca do campo
# Processing Record 23 of Set 2 | severo-kurilsk
# Processing Record 24 of Set 2 | dukat
# Processing Record 25 of Set 2 | yavatmal
# Processing Record 26 of Set 2 | coquimbo
# Processing Record 27 of Set 2 | jamestown
# Processing Record 28 of Set 2 | san patricio
# Processing Record 29 of Set 2 | kodiak
# Processing Record 30 of Set 2 | beaverlodge
# Processing Record 31 of Set 2 | dikson
# Processing Record 32 of Set 2 | leningradskiy
# Processing Record 33 of Set 2 | slave lake
# Processing Record 34 of Set 2 | ancud
# Processing Record 35 of Set 2 | qaanaaq
# Processing Record 36 of Set 2 | mar del plata
# Processing Record 37 of Set 2 | kirkland lake
# Processing Record 38 of Set 2 | cabo san lucas
# Processing Record 39 of Set 2 | grottaglie
# Processing Record 40 of Set 2 | albany
# Processing Record 41 of Set 2 | krasnoselkup
# Processing Record 42 of Set 2 | ahipara
# Processing Record 43 of Set 2 | kaitangata
# Processing Record 44 of Set 2 | valparaiso
# Processing Record 45 of Set 2 | port elizabeth
# Processing Record 46 of Set 2 | raudeberg
# Processing Record 47 of Set 2 | yanan
# City not found. Skipping...
# Processing Record 48 of Set 2 | lalomanu
# City not found. Skipping...
# Processing Record 49 of Set 2 | buin
# Processing Record 50 of Set 2 | okha
# Processing Record 1 of Set 3 | deputatskiy
# Processing Record 2 of Set 3 | nanortalik
# Processing Record 3 of Set 3 | noumea
# Processing Record 4 of Set 3 | kapaa
# Processing Record 5 of Set 3 | pingyin
# Processing Record 6 of Set 3 | acapulco
# Processing Record 7 of Set 3 | pevek
# Processing Record 8 of Set 3 | riyadh
# Processing Record 9 of Set 3 | saskylakh
# Processing Record 10 of Set 3 | ponta do sol
# Processing Record 11 of Set 3 | ribeira grande
# Processing Record 12 of Set 3 | clyde river
# Processing Record 13 of Set 3 | santiago del estero
# Processing Record 14 of Set 3 | adrar
# Processing Record 15 of Set 3 | vaasa
# Processing Record 16 of Set 3 | eydhafushi
# Processing Record 17 of Set 3 | touros
# Processing Record 18 of Set 3 | san juan
# Processing Record 19 of Set 3 | champerico
# Processing Record 20 of Set 3 | suzu
# City not found. Skipping...
# Processing Record 21 of Set 3 | roald
# Processing Record 22 of Set 3 | vaini
# Processing Record 23 of Set 3 | ilulissat
# Processing Record 24 of Set 3 | ngunguru
# Processing Record 25 of Set 3 | lata
# Processing Record 26 of Set 3 | formoso do araguaia
# City not found. Skipping...
# Processing Record 27 of Set 3 | puerto ayora
# Processing Record 28 of Set 3 | lavrentiya
# Processing Record 29 of Set 3 | slavyanka
# Processing Record 30 of Set 3 | contramaestre
# Processing Record 31 of Set 3 | la libertad
# Processing Record 32 of Set 3 | georgetown
# Processing Record 33 of Set 3 | arcata
# Processing Record 34 of Set 3 | lagoa
# Processing Record 35 of Set 3 | norman wells
# Processing Record 36 of Set 3 | nikolskoye
# Processing Record 37 of Set 3 | purpe
# Processing Record 38 of Set 3 | usakos
# Processing Record 39 of Set 3 | tema
# Processing Record 40 of Set 3 | morros
# Processing Record 41 of Set 3 | hasaki
# Processing Record 42 of Set 3 | axim
# Processing Record 43 of Set 3 | rexburg
# Processing Record 44 of Set 3 | faanui
# Processing Record 45 of Set 3 | fairbanks
# Processing Record 46 of Set 3 | port lincoln
# Processing Record 47 of Set 3 | de-kastri
# Processing Record 48 of Set 3 | qaqortoq
# Processing Record 49 of Set 3 | atuona
# Processing Record 50 of Set 3 | selfoss
# Processing Record 1 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 2 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 4 | nome
# Processing Record 4 of Set 4 | inzer
# Processing Record 5 of Set 4 | saint-philippe
# Processing Record 6 of Set 4 | nakusp
# Processing Record 7 of Set 4 | butaritari
# Processing Record 8 of Set 4 | bondowoso
# Processing Record 9 of Set 4 | grindavik
# Processing Record 10 of Set 4 | vao
# Processing Record 11 of Set 4 | suao
# City not found. Skipping...
# Processing Record 12 of Set 4 | fort-shevchenko
# Processing Record 13 of Set 4 | namibe
# Processing Record 14 of Set 4 | husavik
# Processing Record 15 of Set 4 | castro
# Processing Record 16 of Set 4 | provideniya
# Processing Record 17 of Set 4 | venado tuerto
# Processing Record 18 of Set 4 | cusuna
# Processing Record 19 of Set 4 | saldanha
# Processing Record 20 of Set 4 | ust-barguzin
# Processing Record 21 of Set 4 | arlit
# Processing Record 22 of Set 4 | codrington
# Processing Record 23 of Set 4 | lebu
# Processing Record 24 of Set 4 | balkanabat
# Processing Record 25 of Set 4 | iguape
# Processing Record 26 of Set 4 | astana
# Processing Record 27 of Set 4 | shaoguan
# Processing Record 28 of Set 4 | albert lea
# Processing Record 29 of Set 4 | salalah
# Processing Record 30 of Set 4 | huilong
# Processing Record 31 of Set 4 | kavieng
# Processing Record 32 of Set 4 | ugoofaaru
# Processing Record 33 of Set 4 | east london
# Processing Record 34 of Set 4 | san cristobal
# Processing Record 35 of Set 4 | villagarzon
# Processing Record 36 of Set 4 | fortuna
# Processing Record 37 of Set 4 | sioux lookout
# Processing Record 38 of Set 4 | satwas
# Processing Record 39 of Set 4 | batemans bay
# Processing Record 40 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 4 | santa helena de goias
# Processing Record 42 of Set 4 | new york
# Processing Record 43 of Set 4 | dhidhdhoo
# Processing Record 44 of Set 4 | tabou
# Processing Record 45 of Set 4 | puerto escondido
# Processing Record 46 of Set 4 | chardara
# Processing Record 47 of Set 4 | christchurch
# Processing Record 48 of Set 4 | katwijk
# Processing Record 49 of Set 4 | sheltozero
# Processing Record 50 of Set 4 | grand gaube
# Processing Record 1 of Set 5 | safaga
# Processing Record 2 of Set 5 | yaitepec
# City not found. Skipping...
# Processing Record 3 of Set 5 | hobart
# Processing Record 4 of Set 5 | aketi
# Processing Record 5 of Set 5 | port keats
# Processing Record 6 of Set 5 | saint anthony
# Processing Record 7 of Set 5 | villazon
# Processing Record 8 of Set 5 | umm kaddadah
# Processing Record 9 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 5 | poum
# Processing Record 12 of Set 5 | torbay
# Processing Record 13 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 5 | sao joao da barra
# Processing Record 15 of Set 5 | raymondville
# Processing Record 16 of Set 5 | la romana
# Processing Record 17 of Set 5 | sitka
# Processing Record 18 of Set 5 | hovd
# Processing Record 19 of Set 5 | envira
# Processing Record 20 of Set 5 | narsaq
# Processing Record 21 of Set 5 | khatanga
# Processing Record 22 of Set 5 | khandyga
# Processing Record 23 of Set 5 | aguada de pasajeros
# Processing Record 24 of Set 5 | zheleznodorozhnyy
# Processing Record 25 of Set 5 | cidreira
# Processing Record 26 of Set 5 | kirakira
# Processing Record 27 of Set 5 | wewak
# Processing Record 28 of Set 5 | liepaja
# Processing Record 29 of Set 5 | saint george
# Processing Record 30 of Set 5 | mehamn
# Processing Record 31 of Set 5 | dormidontovka
# Processing Record 32 of Set 5 | saint-augustin
# Processing Record 33 of Set 5 | tomatlan
# Processing Record 34 of Set 5 | imbituba
# Processing Record 35 of Set 5 | jizan
# Processing Record 36 of Set 5 | los llanos de aridane
# Processing Record 37 of Set 5 | nagua
# Processing Record 38 of Set 5 | grimari
# City not found. Skipping...
# Processing Record 39 of Set 5 | bandarbeyla
# Processing Record 40 of Set 5 | ostrovnoy
# Processing Record 41 of Set 5 | marawi
# Processing Record 42 of Set 5 | klaksvik
# Processing Record 43 of Set 5 | sinnamary
# Processing Record 44 of Set 5 | meulaboh
# Processing Record 45 of Set 5 | souillac
# Processing Record 46 of Set 5 | mahebourg
# Processing Record 47 of Set 5 | carnarvon
# Processing Record 48 of Set 5 | turceni
# Processing Record 49 of Set 5 | khash
# Processing Record 50 of Set 5 | kahului
# Processing Record 1 of Set 6 | balud
# Processing Record 2 of Set 6 | egvekinot
# Processing Record 3 of Set 6 | chuy
# Processing Record 4 of Set 6 | kodinar
# Processing Record 5 of Set 6 | maniwaki
# Processing Record 6 of Set 6 | broken hill
# Processing Record 7 of Set 6 | verkhoyansk
# Processing Record 8 of Set 6 | ulaangom
# Processing Record 9 of Set 6 | andenes
# Processing Record 10 of Set 6 | nushki
# Processing Record 11 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 12 of Set 6 | hangu
# Processing Record 13 of Set 6 | uglekamensk
# Processing Record 14 of Set 6 | port blair
# Processing Record 15 of Set 6 | jalu
# Processing Record 16 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 17 of Set 6 | malartic
# Processing Record 18 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 19 of Set 6 | palu
# Processing Record 20 of Set 6 | ulladulla
# Processing Record 21 of Set 6 | upernavik
# Processing Record 22 of Set 6 | lermontovka
# Processing Record 23 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 6 | komsomolskiy
# Processing Record 25 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 26 of Set 6 | san pedro
# Processing Record 27 of Set 6 | santa cruz
# Processing Record 28 of Set 6 | zhezkazgan
# Processing Record 29 of Set 6 | diplo
# Processing Record 30 of Set 6 | hofn
# Processing Record 31 of Set 6 | hithadhoo
# Processing Record 32 of Set 6 | masvingo
# Processing Record 33 of Set 6 | beyneu
# Processing Record 34 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 35 of Set 6 | kuala terengganu
# Processing Record 36 of Set 6 | puri
# Processing Record 37 of Set 6 | usak
# Processing Record 38 of Set 6 | tasiilaq
# Processing Record 39 of Set 6 | alofi
# Processing Record 40 of Set 6 | port hardy
# Processing Record 41 of Set 6 | chhatak
# Processing Record 42 of Set 6 | longyearbyen
# Processing Record 43 of Set 6 | coahuayana
# Processing Record 44 of Set 6 | ucluelet
# Processing Record 45 of Set 6 | isangel
# Processing Record 46 of Set 6 | bereda
# Processing Record 47 of Set 6 | huarmey
# Processing Record 48 of Set 6 | half moon bay
# Processing Record 49 of Set 6 | camacha
# Processing Record 50 of Set 6 | holme
# Processing Record 1 of Set 7 | novi bilokorovychi
# Processing Record 2 of Set 7 | surat thani
# Processing Record 3 of Set 7 | atherton
# Processing Record 4 of Set 7 | roebourne
# Processing Record 5 of Set 7 | aklavik
# Processing Record 6 of Set 7 | kita
# Processing Record 7 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 8 of Set 7 | prince rupert
# Processing Record 9 of Set 7 | seoul
# Processing Record 10 of Set 7 | tateyama
# Processing Record 11 of Set 7 | shelburne
# Processing Record 12 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 7 | port-cartier
# Processing Record 14 of Set 7 | skagastrond
# City not found. Skipping...
# Processing Record 15 of Set 7 | bambous virieux
# Processing Record 16 of Set 7 | sabha
# Processing Record 17 of Set 7 | kualakapuas
# Processing Record 18 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 19 of Set 7 | tosham
# Processing Record 20 of Set 7 | xining
# Processing Record 21 of Set 7 | myitkyina
# Processing Record 22 of Set 7 | yulara
# Processing Record 23 of Set 7 | ravar
# Processing Record 24 of Set 7 | mount isa
# Processing Record 25 of Set 7 | pedasi
# Processing Record 26 of Set 7 | vestbygda
# City not found. Skipping...
# Processing Record 27 of Set 7 | wanaka
# Processing Record 28 of Set 7 | praia da vitoria
# Processing Record 29 of Set 7 | tabukiniberu
# City not found. Skipping...
# Processing Record 30 of Set 7 | matara
# Processing Record 31 of Set 7 | bihariganj
# Processing Record 32 of Set 7 | lamar
# Processing Record 33 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 7 | bayshore gardens
# Processing Record 35 of Set 7 | sola
# Processing Record 36 of Set 7 | solnechnyy
# Processing Record 37 of Set 7 | katangli
# Processing Record 38 of Set 7 | strezhevoy
# Processing Record 39 of Set 7 | nanning
# Processing Record 40 of Set 7 | walvis bay
# Processing Record 41 of Set 7 | cherskiy
# Processing Record 42 of Set 7 | ajaccio
# Processing Record 43 of Set 7 | denzlingen
# Processing Record 44 of Set 7 | airai
# Processing Record 45 of Set 7 | taksimo
# Processing Record 46 of Set 7 | chingirlau
# Processing Record 47 of Set 7 | bowen
# Processing Record 48 of Set 7 | calabozo
# Processing Record 49 of Set 7 | karakol
# Processing Record 50 of Set 7 | gunjur
# Processing Record 1 of Set 8 | vestmannaeyjar
# Processing Record 2 of Set 8 | addanki
# Processing Record 3 of Set 8 | beloha
# Processing Record 4 of Set 8 | diego de almagro
# Processing Record 5 of Set 8 | pacific grove
# Processing Record 6 of Set 8 | salto
# Processing Record 7 of Set 8 | fare
# Processing Record 8 of Set 8 | kuching
# Processing Record 9 of Set 8 | oistins
# Processing Record 10 of Set 8 | quatre cocos
# Processing Record 11 of Set 8 | balikpapan
# Processing Record 12 of Set 8 | lakes entrance
# Processing Record 13 of Set 8 | banska bystrica
# Processing Record 14 of Set 8 | paamiut
# Processing Record 15 of Set 8 | pilar
# Processing Record 16 of Set 8 | sibu
# Processing Record 17 of Set 8 | hoshcha
# Processing Record 18 of Set 8 | santa
# Processing Record 19 of Set 8 | sao felix do xingu
# Processing Record 20 of Set 8 | tura
# Processing Record 21 of Set 8 | salamiyah
# Processing Record 22 of Set 8 | ganzhou
# Processing Record 23 of Set 8 | tres marias
# Processing Record 24 of Set 8 | geraldton
# Processing Record 25 of Set 8 | qianan
# Processing Record 26 of Set 8 | san quintin
# Processing Record 27 of Set 8 | bacolod
# Processing Record 28 of Set 8 | tezu
# Processing Record 29 of Set 8 | tuljapur
# Processing Record 30 of Set 8 | brae
# Processing Record 31 of Set 8 | taoudenni
# Processing Record 32 of Set 8 | solsvik
# City not found. Skipping...
# Processing Record 33 of Set 8 | sauda
# Processing Record 34 of Set 8 | abu zabad
# Processing Record 35 of Set 8 | boda
# Processing Record 36 of Set 8 | comodoro rivadavia
# Processing Record 37 of Set 8 | salym
# Processing Record 38 of Set 8 | corn island
# Processing Record 39 of Set 8 | forestville
# Processing Record 40 of Set 8 | kanodar
# Processing Record 41 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 42 of Set 8 | yicheng
# Processing Record 43 of Set 8 | akyab
# Processing Record 44 of Set 8 | south sioux city
# Processing Record 45 of Set 8 | inta
# Processing Record 46 of Set 8 | pangody
# Processing Record 47 of Set 8 | portland
# Processing Record 48 of Set 8 | oyama
# Processing Record 49 of Set 8 | abaete
# Processing Record 50 of Set 8 | benguela
# Processing Record 1 of Set 9 | tual
# Processing Record 2 of Set 9 | pangnirtung
# Processing Record 3 of Set 9 | katsuura
# Processing Record 4 of Set 9 | falealupo
# City not found. Skipping...
# Processing Record 5 of Set 9 | mahibadhoo
# Processing Record 6 of Set 9 | ust-nera
# Processing Record 7 of Set 9 | yanaul
# Processing Record 8 of Set 9 | ilhabela
# Processing Record 9 of Set 9 | mwinilunga
# Processing Record 10 of Set 9 | bryant
# Processing Record 11 of Set 9 | margate
# Processing Record 12 of Set 9 | cockburn town
# Processing Record 13 of Set 9 | constitucion
# Processing Record 14 of Set 9 | colesberg
# Processing Record 15 of Set 9 | vanavara
# Processing Record 16 of Set 9 | armenion
# City not found. Skipping...
# Processing Record 17 of Set 9 | khor
# Processing Record 18 of Set 9 | chilliwack
# Processing Record 19 of Set 9 | tecoanapa
# Processing Record 20 of Set 9 | faya
# Processing Record 21 of Set 9 | boralday
# Processing Record 22 of Set 9 | angoram
# Processing Record 23 of Set 9 | vila velha
# Processing Record 24 of Set 9 | manokwari
# Processing Record 25 of Set 9 | vysokogornyy
# Processing Record 26 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 27 of Set 9 | mayo
# Processing Record 28 of Set 9 | itoman
# Processing Record 29 of Set 9 | kerema
# Processing Record 30 of Set 9 | gushikawa
# Processing Record 31 of Set 9 | esperance
# Processing Record 32 of Set 9 | borogontsy
# Processing Record 33 of Set 9 | izhma
# Processing Record 34 of Set 9 | cabedelo
# Processing Record 35 of Set 9 | buchanan
# Processing Record 36 of Set 9 | korla
# Processing Record 37 of Set 9 | muroto
# Processing Record 38 of Set 9 | umm lajj
# Processing Record 39 of Set 9 | salekhard
# Processing Record 40 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 41 of Set 9 | banda aceh
# Processing Record 42 of Set 9 | honningsvag
# Processing Record 43 of Set 9 | mocuba
# Processing Record 44 of Set 9 | sao borja
# Processing Record 45 of Set 9 | colares
# Processing Record 46 of Set 9 | morondava
# Processing Record 47 of Set 9 | yeppoon
# Processing Record 48 of Set 9 | nouadhibou
# Processing Record 49 of Set 9 | strzelce krajenskie
# Processing Record 50 of Set 9 | kavaratti
# Processing Record 1 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 2 of Set 10 | balykshi
# Processing Record 3 of Set 10 | lohardaga
# Processing Record 4 of Set 10 | dwarka
# Processing Record 5 of Set 10 | sarab
# Processing Record 6 of Set 10 | flin flon
# Processing Record 7 of Set 10 | aberdeen
# Processing Record 8 of Set 10 | chicama
# Processing Record 9 of Set 10 | talnakh
# Processing Record 10 of Set 10 | blacksburg
# Processing Record 11 of Set 10 | tonekabon
# Processing Record 12 of Set 10 | streletskoye
# Processing Record 13 of Set 10 | warrington
# Processing Record 14 of Set 10 | hunza
# City not found. Skipping...
# Processing Record 15 of Set 10 | shwebo
# Processing Record 16 of Set 10 | zhuhai
# Processing Record 17 of Set 10 | chokurdakh
# Processing Record 18 of Set 10 | kruisfontein
# Processing Record 19 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 20 of Set 10 | kingaroy
# Processing Record 21 of Set 10 | bull savanna
# Processing Record 22 of Set 10 | manuk mangkaw
# Processing Record 23 of Set 10 | ossora
# Processing Record 24 of Set 10 | bondo
# Processing Record 25 of Set 10 | nyagan
# Processing Record 26 of Set 10 | tahe
# Processing Record 27 of Set 10 | lengshuijiang
# Processing Record 28 of Set 10 | ruteng
# Processing Record 29 of Set 10 | nishihara
# Processing Record 30 of Set 10 | seminole
# Processing Record 31 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 32 of Set 10 | mpophomeni
# Processing Record 33 of Set 10 | dolinsk
# Processing Record 34 of Set 10 | olafsvik
# Processing Record 35 of Set 10 | itaquyry
# Processing Record 36 of Set 10 | lazaro cardenas
# Processing Record 37 of Set 10 | hervey bay
# Processing Record 38 of Set 10 | knysna
# Processing Record 39 of Set 10 | inirida
# Processing Record 40 of Set 10 | gurgan
# City not found. Skipping...
# Processing Record 41 of Set 10 | iznik
# Processing Record 42 of Set 10 | araguacu
# Processing Record 43 of Set 10 | taian
# Processing Record 44 of Set 10 | anadyr
# Processing Record 45 of Set 10 | springbok
# Processing Record 46 of Set 10 | oppdal
# Processing Record 47 of Set 10 | pisco
# Processing Record 48 of Set 10 | coihaique
# Processing Record 49 of Set 10 | sun city west
# Processing Record 50 of Set 10 | trinidad
# Processing Record 1 of Set 11 | venado
# Processing Record 2 of Set 11 | flinders
# Processing Record 3 of Set 11 | arklow
# Processing Record 4 of Set 11 | biltine
# Processing Record 5 of Set 11 | qasigiannguit
# Processing Record 6 of Set 11 | vanimo
# Processing Record 7 of Set 11 | natal
# Processing Record 8 of Set 11 | glasgow
# Processing Record 9 of Set 11 | batagay
# Processing Record 10 of Set 11 | denpasar
# Processing Record 11 of Set 11 | port augusta
# Processing Record 12 of Set 11 | mahajanga
# Processing Record 13 of Set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 14 of Set 11 | rolla
# Processing Record 15 of Set 11 | gornopravdinsk
# Processing Record 16 of Set 11 | padang
# Processing Record 17 of Set 11 | darnah
# Processing Record 18 of Set 11 | sao gabriel da cachoeira
# Processing Record 19 of Set 11 | matagami
# Processing Record 20 of Set 11 | starosubkhangulovo
# Processing Record 21 of Set 11 | barstow
# Processing Record 22 of Set 11 | karaikkudi
# Processing Record 23 of Set 11 | umm durman
# City not found. Skipping...
# Processing Record 24 of Set 11 | kipen
# Processing Record 25 of Set 11 | henties bay
# Processing Record 26 of Set 11 | rio grande
# Processing Record 27 of Set 11 | sonqor
# Processing Record 28 of Set 11 | umm ruwabah
# City not found. Skipping...
# Processing Record 29 of Set 11 | gizo
# Processing Record 30 of Set 11 | khakhea
# Processing Record 31 of Set 11 | waipawa
# Processing Record 32 of Set 11 | burla
# Processing Record 33 of Set 11 | sibolga
# Processing Record 34 of Set 11 | asau
# Processing Record 35 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 36 of Set 11 | altamira
# Processing Record 37 of Set 11 | narasimharajapura
# Processing Record 38 of Set 11 | lamas
# Processing Record 39 of Set 11 | victoria
# Processing Record 40 of Set 11 | rockport
# Processing Record 41 of Set 11 | berlevag
# Processing Record 42 of Set 11 | caravelas
# Processing Record 43 of Set 11 | teguise
# Processing Record 44 of Set 11 | college
# Processing Record 45 of Set 11 | puerto del rosario
# Processing Record 46 of Set 11 | sakakah
# Processing Record 47 of Set 11 | sistranda
# Processing Record 48 of Set 11 | roma
# Processing Record 49 of Set 11 | saint-joseph
# Processing Record 50 of Set 11 | bilma
# Processing Record 1 of Set 12 | hoima
# Processing Record 2 of Set 12 | tautira
# Processing Record 3 of Set 12 | pemangkat
# Processing Record 4 of Set 12 | shasta lake
# Processing Record 5 of Set 12 | bonavista
# Processing Record 6 of Set 12 | remanso
# Processing Record 7 of Set 12 | beringovskiy
# Processing Record 8 of Set 12 | el fuerte
# Processing Record 9 of Set 12 | richards bay
# Processing Record 10 of Set 12 | isabela
# Processing Record 11 of Set 12 | mount gambier
# Processing Record 12 of Set 12 | thinadhoo
# Processing Record 13 of Set 12 | spartanburg
# Processing Record 14 of Set 12 | vardo
# Processing Record 15 of Set 12 | benjamin hill
# Processing Record 16 of Set 12 | gamba
# Processing Record 17 of Set 12 | dolo
# Processing Record 18 of Set 12 | polyarnyye zori
# Processing Record 19 of Set 12 | odienne
# Processing Record 20 of Set 12 | ahuimanu
# Processing Record 21 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 22 of Set 12 | reconquista
# Processing Record 23 of Set 12 | patrocinio
# Processing Record 24 of Set 12 | umea
# Processing Record 25 of Set 12 | ust-kan
# Processing Record 26 of Set 12 | jiuquan
# Processing Record 27 of Set 12 | wanning
# Processing Record 28 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 29 of Set 12 | candawaga
# City not found. Skipping...
# Processing Record 30 of Set 12 | tricase
# Processing Record 31 of Set 12 | karratha
# Processing Record 32 of Set 12 | hashtrud
# Processing Record 33 of Set 12 | tambopata
# Processing Record 34 of Set 12 | qui nhon
# Processing Record 35 of Set 12 | baruun-urt
# Processing Record 36 of Set 12 | yichun
# Processing Record 37 of Set 12 | hambantota
# Processing Record 38 of Set 12 | evensk
# Processing Record 39 of Set 12 | puerto cabezas
# Processing Record 40 of Set 12 | maniitsoq
# Processing Record 41 of Set 12 | san antonio
# Processing Record 42 of Set 12 | jalingo
# Processing Record 43 of Set 12 | bodden town
# Processing Record 44 of Set 12 | kikwit
# Processing Record 45 of Set 12 | stryn
# Processing Record 46 of Set 12 | oktyabrskoye
# Processing Record 47 of Set 12 | asfi
# Processing Record 48 of Set 12 | we
# City not found. Skipping...
# Processing Record 49 of Set 12 | adelaide
# Processing Record 50 of Set 12 | isla vista
# Processing Record 1 of Set 13 | alyangula
# Processing Record 2 of Set 13 | rio gallegos
# Processing Record 3 of Set 13 | inhambane
# Processing Record 4 of Set 13 | santa cruz del sur
# Processing Record 5 of Set 13 | belyy yar
# Processing Record 6 of Set 13 | gigmoto
# Processing Record 7 of Set 13 | caririacu
# Processing Record 8 of Set 13 | anju
# Processing Record 9 of Set 13 | samfya
# Processing Record 10 of Set 13 | nabire
# Processing Record 11 of Set 13 | mayya
# Processing Record 12 of Set 13 | atambua
# Processing Record 13 of Set 13 | eureka
# Processing Record 14 of Set 13 | nyimba
# Processing Record 15 of Set 13 | aksu
# Processing Record 16 of Set 13 | osakarovka
# Processing Record 17 of Set 13 | gazanjyk
# Processing Record 18 of Set 13 | morant bay
# Processing Record 19 of Set 13 | davila
# Processing Record 20 of Set 13 | zdvinsk
# Processing Record 21 of Set 13 | olden
# Processing Record 22 of Set 13 | awjilah
# Processing Record 23 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 24 of Set 13 | chenzhou
# Processing Record 25 of Set 13 | khani
# Processing Record 26 of Set 13 | ponta delgada
# Processing Record 27 of Set 13 | semirom
# Processing Record 28 of Set 13 | lompoc
# Processing Record 29 of Set 13 | zhicheng
# Processing Record 30 of Set 13 | namatanai
# Processing Record 31 of Set 13 | staraya poltavka
# Processing Record 32 of Set 13 | malangali
# Processing Record 33 of Set 13 | robertsport
# Processing Record 34 of Set 13 | mangrol
# Processing Record 35 of Set 13 | avera
# Processing Record 36 of Set 13 | pontianak
# Processing Record 37 of Set 13 | hayato
# City not found. Skipping...
# Processing Record 38 of Set 13 | viransehir
# Processing Record 39 of Set 13 | vallenar
# Processing Record 40 of Set 13 | rancagua
# Processing Record 41 of Set 13 | sembakung
# Processing Record 42 of Set 13 | paragominas
# Processing Record 43 of Set 13 | troitsko-pechorsk
# Processing Record 44 of Set 13 | preobrazheniye
# Processing Record 45 of Set 13 | alice springs
# Processing Record 46 of Set 13 | north bend
# Processing Record 47 of Set 13 | kontagora
# Processing Record 48 of Set 13 | camargo
# Processing Record 49 of Set 13 | lichinga
# Processing Record 50 of Set 13 | guerrero negro
# Processing Record 1 of Set 14 | lodja
# Processing Record 2 of Set 14 | swan hill
# Processing Record 3 of Set 14 | gobabis
# Processing Record 4 of Set 14 | labuhan
# Processing Record 5 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 6 of Set 14 | tadine
# Processing Record 7 of Set 14 | cabra
# Processing Record 8 of Set 14 | yelizovo
# Processing Record 9 of Set 14 | balimo
# City not found. Skipping...
# Processing Record 10 of Set 14 | uporovo
# Processing Record 11 of Set 14 | goulburn
# Processing Record 12 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 13 of Set 14 | stornoway
# Processing Record 14 of Set 14 | sovetskoye
# Processing Record 15 of Set 14 | naron
# Processing Record 16 of Set 14 | cam ranh
# Processing Record 17 of Set 14 | garavuti
# Processing Record 18 of Set 14 | east norriton
# Processing Record 19 of Set 14 | bayan
# Processing Record 20 of Set 14 | kamenka
# Processing Record 21 of Set 14 | laguna
# Processing Record 22 of Set 14 | tallahassee
# Processing Record 23 of Set 14 | phalombe
# Processing Record 24 of Set 14 | aripuana
# Processing Record 25 of Set 14 | hokitika
# Processing Record 26 of Set 14 | agadez
# Processing Record 27 of Set 14 | fereydunshahr
# Processing Record 28 of Set 14 | oranjestad
# Processing Record 29 of Set 14 | nhulunbuy
# Processing Record 30 of Set 14 | saint-georges
# Processing Record 31 of Set 14 | nanakuli
# Processing Record 32 of Set 14 | nanlong
# Processing Record 33 of Set 14 | port hedland
# Processing Record 34 of Set 14 | pogranichnyy
# Processing Record 35 of Set 14 | aleksandrovsk-sakhalinskiy
# Processing Record 36 of Set 14 | tazovskiy
# Processing Record 37 of Set 14 | uyuni
# Processing Record 38 of Set 14 | heishan
# Processing Record 39 of Set 14 | auki
# Processing Record 40 of Set 14 | gamboma
# Processing Record 41 of Set 14 | aswan
# Processing Record 42 of Set 14 | kosh-agach
# Processing Record 43 of Set 14 | carballo
# Processing Record 44 of Set 14 | killybegs
# Processing Record 45 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 46 of Set 14 | hirara
# Processing Record 47 of Set 14 | susanville
# Processing Record 48 of Set 14 | barnstaple
# Processing Record 49 of Set 14 | canutama
# Processing Record 50 of Set 14 | senekal
# Processing Record 1 of Set 15 | ostersund
# Processing Record 2 of Set 15 | khuzhir
# Processing Record 3 of Set 15 | kieta
# Processing Record 4 of Set 15 | rudsar
# Processing Record 5 of Set 15 | veshenskaya
# Processing Record 6 of Set 15 | pereslavl-zalesskiy
# Processing Record 7 of Set 15 | tuma
# Processing Record 8 of Set 15 | bonthe
# Processing Record 9 of Set 15 | ubinskoye
# Processing Record 10 of Set 15 | dabhoi
# Processing Record 11 of Set 15 | clinton
# Processing Record 12 of Set 15 | bindura
# Processing Record 13 of Set 15 | sao paulo de olivenca
# Processing Record 14 of Set 15 | opuwo
# Processing Record 15 of Set 15 | teocaltiche
# Processing Record 16 of Set 15 | marzuq
# Processing Record 17 of Set 15 | chalisgaon
# Processing Record 18 of Set 15 | nusaybin
# Processing Record 19 of Set 15 | adre
# Processing Record 20 of Set 15 | chapais
# Processing Record 21 of Set 15 | kevsala
# Processing Record 22 of Set 15 | chadiza
# Processing Record 23 of Set 15 | alamosa
# Processing Record 24 of Set 15 | sao filipe
# Processing Record 25 of Set 15 | beaumont
# Processing Record 26 of Set 15 | banepa
# Processing Record 27 of Set 15 | haslev
# Processing Record 28 of Set 15 | do gonbadan
# Processing Record 29 of Set 15 | boden
# Processing Record 30 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 31 of Set 15 | namtsy
# Processing Record 32 of Set 15 | diapaga
# Processing Record 33 of Set 15 | ewo
# Processing Record 34 of Set 15 | rogun
# City not found. Skipping...
# Processing Record 35 of Set 15 | wadi musa
# Processing Record 36 of Set 15 | tambilil
# Processing Record 37 of Set 15 | balakhta
# Processing Record 38 of Set 15 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 15 | palpa
# Processing Record 40 of Set 15 | abai
# Processing Record 41 of Set 15 | beloeil
# Processing Record 42 of Set 15 | dzaoudzi
# Processing Record 43 of Set 15 | xingyi
# Processing Record 44 of Set 15 | nuuk
# Processing Record 45 of Set 15 | loukhi
# Processing Record 46 of Set 15 | nalut
# Processing Record 47 of Set 15 | la ronge
# Processing Record 48 of Set 15 | bubaque
# Processing Record 49 of Set 15 | sur
# Processing Record 50 of Set 15 | pirot
# Processing Record 1 of Set 16 | tupik
# Processing Record 2 of Set 16 | breytovo
# Processing Record 3 of Set 16 | kamaishi
# Processing Record 4 of Set 16 | kandrian
# Processing Record 5 of Set 16 | santa rosa
# Processing Record 6 of Set 16 | yumen
# Processing Record 7 of Set 16 | durham
# Processing Record 8 of Set 16 | longido
# Processing Record 9 of Set 16 | valenca do piaui
# Processing Record 10 of Set 16 | shahrud
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 699

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      baracoa      CU  20.3467  -74.4958     80.65        78          50
# 1        aktau      KZ  43.6500   51.2000     57.78        26          61
# 2     galesong      ID  -5.3166  119.3661     78.82        74          92
# 3     hermanus      ZA -34.4187   19.2345     57.33        80           5
# 4          bud      US  39.4470  -86.1758     65.68        54           0
# 5       neiafu      TO -18.6500 -173.9833     77.68        88          75
# 6        paita      PE  -5.0892  -81.1144     63.72        86          58
# 7      ushuaia      AR -54.8000  -68.3000     44.26        61           0
# 8  antofagasta      CL -23.6500  -70.4000     58.28        75          46
# 9        buala      SB  -8.1450  159.5921     85.48        68          36
#
#    Wind Speed          Current Description
# 0        4.68             scattered clouds
# 1       26.11                broken clouds
# 2        3.80              overcast clouds
# 3       12.19                    clear sky
# 4        8.84                    clear sky
# 5       10.36  light intensity shower rain
# 6       14.56                broken clouds
# 7        6.91                    clear sky
# 8        4.83             scattered clouds
# 9        4.94             scattered clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",
                    "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head()
# Out:
#        City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   baracoa      CU  20.3467  -74.4958     80.65        78          50
# 1     aktau      KZ  43.6500   51.2000     57.78        26          61
# 2  galesong      ID  -5.3166  119.3661     78.82        74          92
# 3  hermanus      ZA -34.4187   19.2345     57.33        80           5
# 4       bud      US  39.4470  -86.1758     65.68        54           0
#
#    Wind Speed Current Description
# 0        4.68    scattered clouds
# 1       26.11       broken clouds
# 2        3.80     overcast clouds
# 3       12.19           clear sky
# 4        8.84           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
